# %% [markdown]
# # About Dataset
#
# [Link to a dataset Water Quality](https://www.kaggle.com/datasets/mssmartypants/water-quality)
#
# ## Context
# This is a set of data created from imaginary data of water quality in an urban environment. I recommend using this dataset for educational purposes, for practice and to acquire the necessary knowledge.
#
# ## Content
# What's inside is more than just rows and columns. You can see water ingredients listed as column names.
#
# ## Description
# All attributes are numeric variables and they are listed bellow:
#
# * aluminium - dangerous if greater than 2.8
# * ammonia - dangerous if greater than 32.5
# * arsenic - dangerous if greater than 0.01
# * barium - dangerous if greater than 2
# * cadmium - dangerous if greater than 0.005
# * chloramine - dangerous if greater than 4
# * chromium - dangerous if greater than 0.1
# * copper - dangerous if greater than 1.3
# * flouride - dangerous if greater than 1.5
# * bacteria - dangerous if greater than 0
# * viruses - dangerous if greater than 0
# * lead - dangerous if greater than 0.015
# * nitrates - dangerous if greater than 10
# * nitrites - dangerous if greater than 1
# * mercury - dangerous if greater than 0.002
# * perchlorate - dangerous if greater than 56
# * radium - dangerous if greater than 5
# * selenium - dangerous if greater than 0.5
# * silver - dangerous if greater than 0.1
# * uranium - dangerous if greater than 0.3
# * is_safe - class attribute {0 - not safe, 1 - safe}
#
# ## Inspiration
# Idea was to create dataset that is good for binary classification and that gives adequate results.

# %% [markdown]
# ## Imports Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline 
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, plot_confusion_matrix

# %% [markdown]
# ## Data

# %%
data = pd.read_csv('waterquality.csv')

# %%
data.head()
# Out:
#    aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  copper  \
# 0       1.65    9.08     0.04    2.85    0.007        0.35      0.83    0.17
# 1       2.32   21.16     0.01    3.31    0.002        5.28      0.68    0.66
# 2       1.01   14.02     0.04    0.58    0.008        4.24      0.53    0.02
# 3       1.36   11.33     0.04    2.96    0.001        7.23      0.03    1.66
# 4       0.92   24.33     0.03    0.20    0.006        2.67      0.69    0.57
#
#    flouride  bacteria  ...   lead  nitrates  nitrites  mercury  perchlorate  \
# 0      0.05      0.20  ...  0.054     16.08      1.13    0.007        37.75
# 1      0.90      0.65  ...  0.100      2.01      1.93    0.003        32.26
# 2      0.99      0.05  ...  0.078     14.16      1.11    0.006        50.28
# 3      1.08      0.71  ...  0.016      1.41      1.29    0.004         9.12
# 4      0.61      0.13  ...  0.117      6.74      1.11    0.003        16.90
#
#    radium  selenium  silver  uranium  is_safe
# 0    6.78      0.08    0.34     0.02        1
# 1    3.21      0.08    0.27     0.05        1
# 2    7.07      0.07    0.44     0.01        0
# 3    1.72      0.02    0.45     0.05        1
# 4    2.41      0.02    0.06     0.02        1
#
# [5 rows x 21 columns]

# %% [markdown]
# we can see in all feature column that the value is numeric

# %%
data.shape
# Out:
# (7999, 21)

# %% [markdown]
# there are a number of samples, namely 7999 rows and 21 columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7999 entries, 0 to 7998
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   aluminium    7999 non-null   float64
#  1   ammonia      7999 non-null   object
#  2   arsenic      7999 non-null   float64
#  3   barium       7999 non-null   float64
#  4   cadmium      7999 non-null   float64
#  5   chloramine   7999 non-null   float64
#  6   chromium     7999 non-null   float64
#  7   copper       7999 non-null   float64
#  8   flouride     7999 non-null   float64
#  9   bacteria     7999 non-null   float64
#  10  viruses      7999 non-null   float64
#  11  lead         7999 non-null   float64
#  12  nitrates     7999 non-null   float64
#  13  nitrites     7999 non-null   float64
#  14  mercury      7999 non-null   float64
#  15  perchlorate  7999 non-null   float64
#  16  radium       7999 non-null   float64
#  17  selenium     7999 non-null   float64
#  18  silver       7999 non-null   float64
#  19  uranium      7999 non-null   float64
#  20  is_safe      7999 non-null   object
# dtypes: float64(19), object(2)
# memory usage: 1.3+ MB

# %% [markdown]
# there is an oddity in the ammonia and is_safe columns that the column should be of type numeric but we see it turns out to be an object
#
# let's see what values are in the ammonia and is_safe columns

# %%
data.is_safe.value_counts()
# Out:
# 0        7084
# 1         912
# #NUM!       3
# Name: is_safe, dtype: int64

# %% [markdown]
# the value #NUM! which makes the is_safe column an object that should be numeric

# %%
missing_value = ['#NUM!', np.nan]
data = pd.read_csv('waterquality.csv', na_values=missing_value )

# %% [markdown]
# let's create a variable for the #NUM! then change the value to NAN and we load the dataset again and add na_values for the missing value

# %%
from jcopml.plot import plot_missing_value
plot_missing_value(data)

# %% [markdown]
# there are missing values in the ammonia and is_safe columns after we change them to NAN

# %%
data.dropna(subset=['ammonia', 'is_safe'], axis=0, inplace=True)

# %% [markdown]
# let's remove the missing value because only a few are missing

# %%
plot_missing_value(data)

# %% [markdown]
# the data is clean from the missing value can be seen from the color change

# %%
data['is_safe'].value_counts()
# Out:
# 0.0    7084
# 1.0     912
# Name: is_safe, dtype: int64

# %% [markdown]
# there are many labels in the column is_safe
# where label 0 is 7084 samples and label 1 is 912 samples

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.countplot(data=data, x='is_safe');

# %% [markdown]
# there is more data for label 0 than for label 1 this causes an unbalanced sample

# %%
plt.figure(figsize=(16,9))
sns.heatmap(data.corr(), annot=True, linewidths=0.5, fmt='.2f', cmap='RdGy', cbar=False);

# %% [markdown]
# In the picture above, you can see the correlation between each table using a heatmap

# %%
plt.ylim(-1,1)
data.corr()['is_safe'][:-1].sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# In the image above we can see the correlation between the feature and the target label, where aluminium is the column with the highest correlation with the target label

# %%
ax = sns.scatterplot(data=data, x='aluminium', y='chloramine', hue='is_safe', alpha=0.7)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1));

# %% [markdown]
# let's check the relationship between aluminium and chloramine with the scatterplot, we can see that the value between the columns is very random with the target label where when the aluminum value is above zero the value becomes even more random

# %% [markdown]
# ## Splitting Data

# %%
X = data.drop('is_safe', axis=1)  
y = data['is_safe']

# %% [markdown]
# separate between the feature column and the label column where the label column is only is_safe

# %%
X.head()
# Out:
#    aluminium  ammonia  arsenic  barium  cadmium  chloramine  chromium  copper  \
# 0       1.65     9.08     0.04    2.85    0.007        0.35      0.83    0.17
# 1       2.32    21.16     0.01    3.31    0.002        5.28      0.68    0.66
# 2       1.01    14.02     0.04    0.58    0.008        4.24      0.53    0.02
# 3       1.36    11.33     0.04    2.96    0.001        7.23      0.03    1.66
# 4       0.92    24.33     0.03    0.20    0.006        2.67      0.69    0.57
#
#    flouride  bacteria  viruses   lead  nitrates  nitrites  mercury  \
# 0      0.05      0.20    0.000  0.054     16.08      1.13    0.007
# 1      0.90      0.65    0.650  0.100      2.01      1.93    0.003
# 2      0.99      0.05    0.003  0.078     14.16      1.11    0.006
# 3      1.08      0.71    0.710  0.016      1.41      1.29    0.004
# 4      0.61      0.13    0.001  0.117      6.74      1.11    0.003
#
#    perchlorate  radium  selenium  silver  uranium
# 0        37.75    6.78      0.08    0.34     0.02
# 1        32.26    3.21      0.08    0.27     0.05
# 2        50.28    7.07      0.07    0.44     0.01
# 3         9.12    1.72      0.02    0.45     0.05
# 4        16.90    2.41      0.02    0.06     0.02

# %% [markdown]
# variable X has been separated from the label

# %%
y.head().to_frame()
# Out:
#    is_safe
# 0      1.0
# 1      1.0
# 2      0.0
# 3      1.0
# 4      1.0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y , random_state=77)
print(f"X_train : {X_train.shape} y_train : {y_train.shape} X_test : {X_test.shape} y_test : {y_test.shape}")
# Out:
# X_train : (6396, 20) y_train : (6396,) X_test : (1600, 20) y_test : (1600,)

# %% [markdown]
# let's train_test_split to divide the size of the training data and test data by 20% split and use the parameter stratify for the labels to make the splits even

# %% [markdown]
# ## Create Model with Pipeline

# %%
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('algo', SVC())
])

# %% [markdown]
# use the pipeline for the scaler data train and test processes to prevent data leakage and add the SVC algorithm for the model creation process

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('algo', SVC())])

# %% [markdown]
# fit data X_train and y_train using pipeline

# %%
y_pred_pipeline = pipeline.predict(X_test)
print(f'score train : {pipeline.score(X_train,y_train)} score test : {pipeline.score(X_test,y_test)}\n')
print(classification_report(y_test, y_pred_pipeline))
plot_confusion_matrix(pipeline, X_test, y_test, colorbar=False, cmap='Reds');
# Out:
# score train : 0.9521575984990619 score test : 0.951875
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      1418
#          1.0       0.95      0.61      0.74       182
#
#     accuracy                           0.95      1600
#    macro avg       0.95      0.80      0.86      1600
# weighted avg       0.95      0.95      0.95      1600

# %% [markdown]
# <b>let's check the score results from the fit results using the pipeline,
# For the score results for the train data, we get 95,21% accuracy and for the test data we get 95,18% accuracy as well, that's great!! and the prediction results guess that there are 6 errors in guessing the label 0 is 1 which is a false positive, that's very good because our goal is to minimize the error in false positives

# %% [markdown]
# ## Using GridSearchCV

# %%
parameter = {
    'algo__C':[0.01,0.1,0.5,1,3,5],
    'algo__kernel':['rbf','linear'],
    'algo__gamma':['scale','auto'],
}

# %% [markdown]
# parameters GridSearchCV for the support vector machine algorithm

# %%
model = GridSearchCV(estimator=pipeline, param_grid=parameter, cv=5, n_jobs=-1)
model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('algo', SVC())]),
#              n_jobs=-1,
#              param_grid={'algo__C': [0.01, 0.1, 0.5, 1, 3, 5],
#                          'algo__gamma': ['scale', 'auto'],
#                          'algo__kernel': ['rbf', 'linear']})

# %% [markdown]
# use GridSearchCV to combine the pipeline and fill param_grid with the parameters we created earlier, use 5 fold cross validation and refit the model

# %%
print(f'{model.best_params_}\n')
# Out:
# {'algo__C': 5, 'algo__gamma': 'scale', 'algo__kernel': 'rbf'}

# %% [markdown]
# the best parameter for SVC is C : 5, gamma : scale and kernel : rbf

# %%
y_pred_grid = model.predict(X_test)
print(f'score train : {model.score(X_train,y_train)} | score test : {model.score(X_test,y_test)}\n')
print(classification_report(y_test, y_pred_grid))
plot_confusion_matrix(model, X_test, y_test, colorbar=False, cmap='Reds');
# Out:
# score train : 0.9738899312070044 | score test : 0.95875
#
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.98      1418
#          1.0       0.91      0.71      0.80       182
#
#     accuracy                           0.96      1600
#    macro avg       0.94      0.85      0.89      1600
# weighted avg       0.96      0.96      0.96      1600

# %% [markdown]
# <b>let's check again the score results from the fit results using GridSearchCV,
# For the scores for the training data, we get an accuracy of 97.38% and for the test data, we get an accuracy of 95.87%, for the training data we get a 2% increase, and for the test data, it doesn't change much!! and the results of the guess prediction there are 13 errors in guessing the label 0 is 1 which is a false positive, using GridSearchCV doesn't really affect the score model results instead it adds to the error in guessing the label 0 is 1 it's dangerous, so it's better for us to use a model without GridSearchCV for this case.
