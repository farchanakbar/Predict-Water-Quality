# %% [markdown]
# Assalamualaikum wr. wb
#
# Hi! Introducing me Farchan Akbar, I am a graduate of informatics engineering in 2022 and 22 years old.
# I really want to work in the data scientist field. I hope this portfolio can be taken into consideration in the recruitment process, thank you
#
# Sorry if my English is bad :') I hope you like it!

# %% [markdown]
# # About Dataset
#
# [Link to a dataset diabetes](https://www.kaggle.com/datasets/mssmartypants/water-quality)
#
# ## Context
# This is a set of data created from imaginary data of water quality in an urban environment. I recommend using this dataset for educational purposes, for practice and to acquire the necessary knowledge.
#
# ## Content
# What's inside is more than just rows and columns. You can see water ingredients listed as column names.
#
# ## Description
# All attributes are numeric variables and they are listed bellow:
#
# * aluminium - dangerous if greater than 2.8
# * ammonia - dangerous if greater than 32.5
# * arsenic - dangerous if greater than 0.01
# * barium - dangerous if greater than 2
# * cadmium - dangerous if greater than 0.005
# * chloramine - dangerous if greater than 4
# * chromium - dangerous if greater than 0.1
# * copper - dangerous if greater than 1.3
# * flouride - dangerous if greater than 1.5
# * bacteria - dangerous if greater than 0
# * viruses - dangerous if greater than 0
# * lead - dangerous if greater than 0.015
# * nitrates - dangerous if greater than 10
# * nitrites - dangerous if greater than 1
# * mercury - dangerous if greater than 0.002
# * perchlorate - dangerous if greater than 56
# * radium - dangerous if greater than 5
# * selenium - dangerous if greater than 0.5
# * silver - dangerous if greater than 0.1
# * uranium - dangerous if greater than 0.3
# * is_safe - class attribute {0 - not safe, 1 - safe}
#
# ## Inspiration
# Idea was to create dataset that is good for binary classification and that gives adequate results.

# %% [markdown]
# ## Imports Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from wordcloud import WordCloud
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data

# %%
# load dataset
data = pd.read_csv('waterquality.csv')

# %%
# 5 first rows
data.head()
# Out:
#    aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  copper  \
# 0       1.65    9.08     0.04    2.85    0.007        0.35      0.83    0.17
# 1       2.32   21.16     0.01    3.31    0.002        5.28      0.68    0.66
# 2       1.01   14.02     0.04    0.58    0.008        4.24      0.53    0.02
# 3       1.36   11.33     0.04    2.96    0.001        7.23      0.03    1.66
# 4       0.92   24.33     0.03    0.20    0.006        2.67      0.69    0.57
#
#    flouride  bacteria  ...   lead  nitrates  nitrites  mercury  perchlorate  \
# 0      0.05      0.20  ...  0.054     16.08      1.13    0.007        37.75
# 1      0.90      0.65  ...  0.100      2.01      1.93    0.003        32.26
# 2      0.99      0.05  ...  0.078     14.16      1.11    0.006        50.28
# 3      1.08      0.71  ...  0.016      1.41      1.29    0.004         9.12
# 4      0.61      0.13  ...  0.117      6.74      1.11    0.003        16.90
#
#    radium  selenium  silver  uranium  is_safe
# ...

# %%
# check total rows and columns, we have 7999 rows and 21 columns
data.shape
# Out:
# (7999, 21)

# %%
# get information of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7999 entries, 0 to 7998
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   aluminium    7999 non-null   float64
#  1   ammonia      7999 non-null   object
#  2   arsenic      7999 non-null   float64
#  3   barium       7999 non-null   float64
#  4   cadmium      7999 non-null   float64
#  5   chloramine   7999 non-null   float64
#  6   chromium     7999 non-null   float64
#  7   copper       7999 non-null   float64
#  8   flouride     7999 non-null   float64
#  9   bacteria     7999 non-null   float64
#  10  viruses      7999 non-null   float64
#  11  lead         7999 non-null   float64
#  12  nitrates     7999 non-null   float64
#  13  nitrites     7999 non-null   float64
#  14  mercury      7999 non-null   float64
#  15  perchlorate  7999 non-null   float64
#  16  radium       7999 non-null   float64
#  17  selenium     7999 non-null   float64
# ...

# %%
# check missing value
data.isnull().sum()
# Out:
# aluminium      0
# ammonia        0
# arsenic        0
# barium         0
# cadmium        0
# chloramine     0
# chromium       0
# copper         0
# flouride       0
# bacteria       0
# viruses        0
# lead           0
# nitrates       0
# nitrites       0
# mercury        0
# perchlorate    0
# radium         0
# selenium       0
# silver         0
# uranium        0
# is_safe        0
# dtype: int64

# %%
# check duplicated of data
data.duplicated().sum()
# Out:
# 0

# %%
# check detail value of columns
data.describe().transpose()
# Out:
#               count       mean        std  min    25%    50%     75%    max
# aluminium    7999.0   0.666158   1.265145  0.0  0.040  0.070   0.280   5.05
# arsenic      7999.0   0.161445   0.252590  0.0  0.030  0.050   0.100   1.05
# barium       7999.0   1.567715   1.216091  0.0  0.560  1.190   2.480   4.94
# cadmium      7999.0   0.042806   0.036049  0.0  0.008  0.040   0.070   0.13
# chloramine   7999.0   2.176831   2.567027  0.0  0.100  0.530   4.240   8.68
# chromium     7999.0   0.247226   0.270640  0.0  0.050  0.090   0.440   0.90
# copper       7999.0   0.805857   0.653539  0.0  0.090  0.750   1.390   2.00
# flouride     7999.0   0.771565   0.435373  0.0  0.405  0.770   1.160   1.50
# bacteria     7999.0   0.319665   0.329485  0.0  0.000  0.220   0.610   1.00
# viruses      7999.0   0.328583   0.378096  0.0  0.002  0.008   0.700   1.00
# lead         7999.0   0.099450   0.058172  0.0  0.048  0.102   0.151   0.20
# ...

# %% [markdown]
# * against the #NUM! which is not detected in the missing value because the type is object, so we have to create a variable to remove this missing value then we load the dataset again

# %%
# check label
sns.countplot(data=data, x='is_safe');

# %%
# create variabel to detect missing value #NUM!
missing_value = ['#NUM!', np.nan]
data = pd.read_csv('waterquality.csv', na_values=missing_value )

# %%
# we have 3 missing value of columns ammonia and is_safe
data.isnull().sum()
# Out:
# aluminium      0
# ammonia        3
# arsenic        0
# barium         0
# cadmium        0
# chloramine     0
# chromium       0
# copper         0
# flouride       0
# bacteria       0
# viruses        0
# lead           0
# nitrates       0
# nitrites       0
# mercury        0
# perchlorate    0
# radium         0
# selenium       0
# silver         0
# uranium        0
# is_safe        3
# dtype: int64

# %%
# remove missing value
data = data.dropna(subset=['is_safe', 'ammonia'], axis=0)

# %%
data.isnull().sum()
# Out:
# aluminium      0
# ammonia        0
# arsenic        0
# barium         0
# cadmium        0
# chloramine     0
# chromium       0
# copper         0
# flouride       0
# bacteria       0
# viruses        0
# lead           0
# nitrates       0
# nitrites       0
# mercury        0
# perchlorate    0
# radium         0
# selenium       0
# silver         0
# uranium        0
# is_safe        0
# dtype: int64

# %%
# plot again to check missing value is gone
sns.countplot(data=data, x='is_safe');

# %%
# check total label, we have 7084 sample for label 0 and 912 for label 1
data['is_safe'].value_counts()
# Out:
# 0.0    7084
# 1.0     912
# Name: is_safe, dtype: int64

# %%
# cek correlation of dataset
plt.figure(figsize=(16,9))
sns.heatmap(data.corr(), annot=True, linewidths=0.5);

# %%
# check correlation again with plot histogram
data.corr()['is_safe'][:-1].sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
ax = sns.scatterplot(data=data, x='aluminium', y='chloramine', hue='is_safe', alpha=0.7)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1));

# %% [markdown]
# ## Splitting Data

# %%
X = data.drop('is_safe', axis=1) # for feature
y = data['is_safe'] # for target

# %%
# 5 first fows of feature
X.head()
# Out:
#    aluminium  ammonia  arsenic  barium  cadmium  chloramine  chromium  copper  \
# 0       1.65     9.08     0.04    2.85    0.007        0.35      0.83    0.17
# 1       2.32    21.16     0.01    3.31    0.002        5.28      0.68    0.66
# 2       1.01    14.02     0.04    0.58    0.008        4.24      0.53    0.02
# 3       1.36    11.33     0.04    2.96    0.001        7.23      0.03    1.66
# 4       0.92    24.33     0.03    0.20    0.006        2.67      0.69    0.57
#
#    flouride  bacteria  viruses   lead  nitrates  nitrites  mercury  \
# 0      0.05      0.20    0.000  0.054     16.08      1.13    0.007
# 1      0.90      0.65    0.650  0.100      2.01      1.93    0.003
# 2      0.99      0.05    0.003  0.078     14.16      1.11    0.006
# 3      1.08      0.71    0.710  0.016      1.41      1.29    0.004
# 4      0.61      0.13    0.001  0.117      6.74      1.11    0.003
#
#    perchlorate  radium  selenium  silver  uranium
# ...

# %%
# 5 first rows of target
y.head().to_frame()
# Out:
#    is_safe
# 0      1.0
# 1      1.0
# 2      0.0
# 3      1.0
# 4      1.0

# %%
from sklearn.model_selection import train_test_split

# %%
# use 20% for data test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
# check shape data train and test
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (6396, 20)
# (6396,)
# (1600, 20)
# (1600,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
# fit and tranform data train and test with standardscaler
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.48609022, -0.47763684, -0.28128987, ..., -0.69177987,
#         -0.67801047,  0.93666606],
#        [-0.49409669,  1.58745883, -0.47955771, ..., -1.38769431,
#         -0.60845309,  1.68250063],
#        [-0.45406433,  0.97524518, -0.43990414, ...,  0.70004902,
#         -0.88668262, -0.55500307],
#        ...,
#        [ 1.96389009,  1.53118919, -0.08302202, ...,  1.39596346,
#         -0.12155142,  1.68250063],
#        [ 1.19526882,  0.2910064 ,  1.58242786, ...,  0.00413458,
#         -0.81712524, -0.18208578],
#        [-0.4620708 , -1.57489476, -0.55886485, ..., -0.69177987,
#         -0.88668262, -0.55500307]])

# %%
X_test_scaled
# Out:
# array([[-0.51010963, -0.52265255, -0.32094344, ..., -0.69177987,
#         -0.60845309,  1.30958335],
#        [-0.5181161 , -0.84789105, -0.51921128, ...,  0.70004902,
#         -0.12155142,  1.30958335],
#        [-0.4060255 , -0.70834235,  1.34450645, ..., -1.38769431,
#          2.31295696,  0.93666606],
#        ...,
#        [-0.50210316, -1.21589447,  2.65307422, ...,  0.70004902,
#          2.10428481, -0.55500307],
#        [-0.47007727, -0.55078737, -0.32094344, ..., -0.69177987,
#         -0.74756786, -1.67375491],
#        [-0.44605786,  0.88521376, -0.36059701, ..., -1.38769431,
#         -0.33022356,  0.56374878]])

# %% [markdown]
# ## Create Model

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, plot_confusion_matrix

# %%
# name variabel of model
svc = SVC()
dtc = DecisionTreeClassifier()
rfc = RandomForestClassifier(n_estimators=200)
gbc = GradientBoostingClassifier()

# %%
# create function for fit and predict model and report predict
def model(model):
    model.fit(X_train_scaled,y_train)
    y_pred = model.predict(X_test_scaled)
    print(classification_report(y_test,y_pred))
    plot_confusion_matrix(model, X_test_scaled, y_test);

# %%
# prediction report from the model support vector machine
print('Support Vectore Machine')
print('\n')
model(svc)
# Out:
# Support Vectore Machine
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.99      0.97      1411
#          1.0       0.89      0.53      0.66       189
#
#     accuracy                           0.94      1600
#    macro avg       0.92      0.76      0.81      1600
# weighted avg       0.93      0.94      0.93      1600

# %%
# prediction report from the model DecisionTreeClassifier
print('DecisionTreeClassifier')
print('\n')
model(dtc)
# Out:
# DecisionTreeClassifier
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.98      0.97      1411
#          1.0       0.80      0.75      0.78       189
#
#     accuracy                           0.95      1600
#    macro avg       0.88      0.86      0.87      1600
# weighted avg       0.95      0.95      0.95      1600

# %%
# prediction report from the model RandomForestClassifier
print('RandomForestClassifier')
print('\n')
model(rfc)
# Out:
# RandomForestClassifier
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.99      0.97      1411
#          1.0       0.94      0.65      0.76       189
#
#     accuracy                           0.95      1600
#    macro avg       0.95      0.82      0.87      1600
# weighted avg       0.95      0.95      0.95      1600

# %%
# prediction report from the model GradientBoostingClassifier
print('GradientBoostingClassifier')
model(gbc)
# Out:
# GradientBoostingClassifier
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.97      1411
#          1.0       0.91      0.67      0.77       189
#
#     accuracy                           0.95      1600
#    macro avg       0.93      0.83      0.87      1600
# weighted avg       0.95      0.95      0.95      1600

# %% [markdown]
# ## Using GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
# parameter of GradientBoostingClassifier
param_grid = {"n_estimators":[1,5,10,20,40,100],'max_depth':[3,4,5,6]}

# %%
grid = GridSearchCV(gbc,param_grid, verbose=2)

# %%
model(grid)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] END ........................max_depth=3, n_estimators=1; total time=   0.0s
# [CV] END ........................max_depth=3, n_estimators=1; total time=   0.0s
# [CV] END ........................max_depth=3, n_estimators=1; total time=   0.0s
# [CV] END ........................max_depth=3, n_estimators=1; total time=   0.0s
# [CV] END ........................max_depth=3, n_estimators=1; total time=   0.0s
# [CV] END ........................max_depth=3, n_estimators=5; total time=   0.1s
# [CV] END ........................max_depth=3, n_estimators=5; total time=   0.1s
# [CV] END ........................max_depth=3, n_estimators=5; total time=   0.1s
# [CV] END ........................max_depth=3, n_estimators=5; total time=   0.0s
# [CV] END ........................max_depth=3, n_estimators=5; total time=   0.0s
# [CV] END .......................max_depth=3, n_estimators=10; total time=   0.2s
# ...

# %% [markdown]
# <b> based on the results of making the model, I prefer the model with the random forest classifier because there is a slight error in guessing a False Positive where we know that label 0 not safe and 1 is safe,
#
# I hope you like it,
# sorry if my English is bad :(
